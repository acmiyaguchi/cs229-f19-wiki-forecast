# %%
# optimization to save on shuffle space
spark.conf.set("spark.serializer", "org.apache.spark.serializer.KryoSerializer")

# this needs to be set to a reasonable number on a local machine
spark.conf.set("spark.sql.shuffle.partitions", "16")

spark.conf.set("spark.sql.execution.arrow.enabled", "true")

# hack to provide a posix like path in Windows
from pathlib import Path
checkpoint_dir = "file:///" + "/".join(
    (Path("..").resolve() / "data/tmp").parts[1:]
)
print(checkpoint_dir)

# needed by GraphFrames to persist intermediate results to local disk
sc.setCheckpointDir(checkpoint_dir)
# Out:
# file:///Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp

# %% [markdown]
# ### Recursive bi-partitioning

# %%
import pyspark.sql.functions as F
from graphframes import GraphFrame
import scipy.sparse as sp
from scipy.sparse.linalg import eigsh
from scipy.sparse.csgraph import laplacian
import numpy as np
import pandas as pd
from pyspark.sql.functions import pandas_udf, PandasUDFType
from typing import List


def sparse_matrix_from_edgelist(edges):
    n = edges["src"].max()
    ones = np.ones(len(edges["dst"]))
    return sp.coo_matrix(
        (ones, (edges["src"], edges["dst"])), 
        shape=(n+1, n+1)
    ).tocsr()
    
def fiedler_vector(g):
    L = laplacian(g)
    # ordered by smallest eigenvalue
    _, v = eigsh(L, k=2)
    # fiedler vector is the second smallest eigenvalue
    return v[:,1]


@pandas_udf("id long, value double", PandasUDFType.GROUPED_MAP)
# Input/output are both a pandas.DataFrame
def compute_fiedler(pdf):
    #relabel?
    g = sparse_matrix_from_edgelist(pdf)
    vec = fiedler_vector(g)
    return pd.DataFrame([{"id": i, "value": v} for i, v in enumerate(vec)])


def induce_graph(graph, relabel=True):
    """Remove extra edges that do not belong to the graph"""
    # small dataframe for reindexing/relabeling
    # O(50mb)
    rank = (
        graph.vertices
        .select("id", F.expr("row_number() over (order by id)").alias("rank"))
        # ensure 0 index for mapping into a scipy.sparse matrix
        .withColumn("rank", F.expr("rank - 1"))
    )
    vertices = graph.vertices.join(F.broadcast(rank), on="id", how="inner")
    edges = (
        graph.edges.join(
            vertices.selectExpr("id as src", "rank as relabeled_src"),
            on="src", 
            how="inner"
        ).join(
            vertices.selectExpr("id as dst", "rank as relabeled_dst"), 
            on="dst", 
            how="inner"
        )
    )

    if relabel:
        vertices = (
            vertices
            .withColumn("original_id", F.col("id"))
            .withColumn("id", F.col("rank"))
        )
        edges = edges.selectExpr("relabeled_src as src", "relabeled_dst as dst")
    vertices = vertices.drop("rank")
    edges = edges.drop("relabeled_src").drop("relabeled_dst")

    return GraphFrame(vertices, edges)


def sample_graph(pages, pagelinks, sampling_ratio, relabel=True):
    vertices = pages.sample(sampling_ratio)
    edges = pagelinks.selectExpr("from as src", "dest as dst")
    graph = induce_graph(GraphFrame(vertices, edges), False)
    # only do this when sampling, on the full dataset this is a waste of time
    components = graph.connectedComponents()
    components.cache()
    largest_component = (
        components
        .groupBy("component")
        .count()
        .orderBy(F.desc("count"))
        .limit(1)
        .select("component")
    )
    return induce_graph(GraphFrame(components.join(largest_component, on="component", how="inner"), graph.edges))


def recursive_bipartition(graph: GraphFrame, max_iter: int = 2) -> GraphFrame:
    """
    Assumes the input graph has been relabeled, which is required for performance of
    scipy.linalg.eigsh.
    """

    def undo_relabel(vertices):
        return vertices.withColumn("id", F.col("original_id")).drop("original_id")

    
    def bipartition(graph: GraphFrame, partitions: List[str] = [], iteration: int = 0):
        
        partition = f"sign_{iteration}"
        fiedler_value = f"fiedler_{iteration}"
        fiedler = (
            graph
            .edges
            # necessary for collecting all edges to a single worker
            .withColumn("part", F.lit(True))
            .groupBy("part")
            .apply(compute_fiedler)
            .withColumn(partition, F.expr("value >= 0").astype("boolean"))
            .selectExpr("id", f"value as {fiedler_value}", partition)
        )
        
        # NOTE: assumes relabeling, reverse the relabeling process
        vertices = graph.vertices.join(fiedler, on="id", how="left")
        parted_graph = GraphFrame(vertices, graph.edges)
        
        if iteration == max_iter:
            return undo_relabel(parted_graph.vertices)
        else:
            positive_vertices = bipartition(
                induce_graph(
                    GraphFrame(
                        parted_graph.vertices.where(f"{partition}"),
                        parted_graph.edges,
                    ),
                    relabel=True,
                ),
                partitions + [partition],
                iteration + 1,
            )
            negative_vertices = bipartition(
                induce_graph(
                    GraphFrame(
                        parted_graph.vertices.where(f"NOT {partition}"),
                        parted_graph.edges,
                    ),
                    relabel=True,
                ),
                partitions + [partition],
                iteration + 1,
            )
            # reusing the index, should this be saved?
            return undo_relabel(
                positive_vertices
                .union(negative_vertices)
                .join(vertices.select("id", "original_id"), on="id", how="inner")
            )

    return bipartition(induce_graph(graph, relabel=True))

# %%
pages_path = "../data/enwiki/pages"
pagelinks_path = "../data/enwiki/pagelinks"

pages = spark.read.parquet(pages_path)
pagelinks = spark.read.parquet(pagelinks_path)

# %%
g = sample_graph(pages, pagelinks, 0.05)
g.cache()
# %time print(g.vertices.count(), g.edges.count())
# Out:
# 210311 1120432
# Wall time: 1min 6s

# %%
result = recursive_bipartition(g, max_iter=2)
signs = [c for c in result.columns if c.startswith("sign_")]
# %time result.groupBy(signs).count().show()
# Out:
# +------+------+------+-----+
# |sign_0|sign_1|sign_2|count|
# +------+------+------+-----+
# | false| false| false|30129|
# |  true|  true| false|20973|
# | false|  true| false|30901|
# |  true| false|  true|23266|
# |  true|  true|  true|20957|
# |  true|  true|  null|    7|
# | false| false|  true|29767|
# | false|  true|  true|31279|
# |  true| false| false|23029|
# |  true| false|  null|    2|
# | false| false|  null|    1|
# +------+------+------+-----+
#
# Wall time: 6min 5s

# %%
recursive_bipartition(g, max_iter=2).explain()
# Out:
# == Physical Plan ==
# *(3973) Project [original_id#10170185 AS id#10171090, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, fiedler_0#10170231, sign_0#10170227, fiedler_1#10170327, sign_1#10170323, fiedler_2#10170433, sign_2#10170429]
# +- *(3973) SortMergeJoin [id#10170630], [id#10170193], Inner
#    :- *(3953) Sort [id#10170630 ASC NULLS FIRST], false, 0
#    :  +- Exchange hashpartitioning(id#10170630, 16)
#    :     +- Union
#    :        :- *(1976) Project [original_id#10170275 AS id#10170630, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, fiedler_0#10170231, sign_0#10170227, fiedler_1#10170327, sign_1#10170323, fiedler_2#10170433, sign_2#10170429]
#    :        :  +- *(1976) SortMergeJoin [id#10170449], [id#10170285], Inner
#    :        :     :- *(1839) Sort [id#10170449 ASC NULLS FIRST], false, 0
#    :        :     :  +- Exchange hashpartitioning(id#10170449, 16)
#    :        :     :     +- Union
#    :        :     :        :- *(919) Project [original_id#10170375 AS id#10170449, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, fiedler_0#10170231, sign_0#10170227, fiedler_1#10170327, sign_1#10170323, fiedler_2#10170433, sign_2#10170429]
#    :        :     :        :  +- SortMergeJoin [cast(id#10170387 as bigint)], [id#10170425L], LeftOuter
#    :        :     :        :     :- *(273) Sort [cast(id#10170387 as bigint) ASC NULLS FIRST], false, 0
#    :        :     :        :     :  +- Exchange hashpartitioning(cast(id#10170387 as bigint), 16)
#    :        :     :        :     :     +- *(272) Project [rank#10170345 AS id#10170387, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, id#10170285 AS original_id#10170375, fiedler_0#10170231, sign_0#10170227, fiedler_1#10170327, sign_1#10170323]
#    :        :     :        :     :        +- *(272) BroadcastHashJoin [id#10170285], [id#10170348], Inner, BuildRight
#    :        :     :        :     :           :- *(272) Project [id#10170285, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, fiedler_0#10170231, sign_0#10170227, fiedler_1#10170327, sign_1#10170323]
#    :        :     :        :     :           :  +- *(272) SortMergeJoin [cast(id#10170285 as bigint)], [id#10170319L], Inner
#    :        :     :        :     :           :     :- *(39) Sort [cast(id#10170285 as bigint) ASC NULLS FIRST], false, 0
#    :        :     :        :     :           :     :  +- Exchange hashpartitioning(cast(id#10170285 as bigint), 16)
#    :        :     :        :     :           :     :     +- *(38) Project [rank#10170247 AS id#10170285, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, fiedler_0#10170231, sign_0#10170227]
#    :        :     :        :     :           :     :        +- *(38) BroadcastHashJoin [id#10170193], [id#10170250], Inner, BuildRight
#    :        :     :        :     :           :     :           :- *(38) Project [id#10170193, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, fiedler_0#10170231, sign_0#10170227]
#    :        :     :        :     :           :     :           :  +- *(38) SortMergeJoin [cast(id#10170193 as bigint)], [id#10170223L], Inner
#    :        :     :        :     :           :     :           :     :- *(4) Sort [cast(id#10170193 as bigint) ASC NULLS FIRST], false, 0
#    :        :     :        :     :           :     :           :     :  +- Exchange hashpartitioning(cast(id#10170193 as bigint), 16)
#    :        :     :        :     :           :     :           :     :     +- *(3) Project [rank#10170159 AS id#10170193, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901]
#    :        :     :        :     :           :     :           :     :        +- *(3) BroadcastHashJoin [id#10095002], [id#10170162], Inner, BuildRight
#    :        :     :        :     :           :     :           :     :           :- *(3) Filter isnotnull(id#10095002)
#    :        :     :        :     :           :     :           :     :           :  +- InMemoryTableScan [id#10095002, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901], [isnotnull(id#10095002)]
#    :        :     :        :     :           :     :           :     :           :        +- InMemoryRelation [id#10095002, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, original_id#10094994], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :              +- *(10) Project [rank#10094962 AS id#10095002, component#10094895L, title#10094899, is_redirect#10094900, is_new#10094901, id#10094898 AS original_id#10094994]
#    :        :     :        :     :           :     :           :     :           :                 +- *(10) BroadcastHashJoin [id#10094898], [id#10094965], Inner, BuildRight
#    :        :     :        :     :           :     :           :     :           :                    :- *(10) Project [component#10094895L, id#10094898, title#10094899, is_redirect#10094900, is_new#10094901]
#    :        :     :        :     :           :     :           :     :           :                    :  +- *(10) BroadcastHashJoin [component#10094895L], [component#10094952L], Inner, BuildRight
#    :        :     :        :     :           :     :           :     :           :                    :     :- *(10) Filter (isnotnull(component#10094895L) && isnotnull(id#10094898))
#    :        :     :        :     :           :     :           :     :           :                    :     :  +- InMemoryTableScan [id#10094898, title#10094899, is_redirect#10094900, is_new#10094901, component#10094895L], [isnotnull(component#10094895L), isnotnull(id#10094898)]
#    :        :     :        :     :           :     :           :     :           :                    :     :        +- InMemoryRelation [id#10094898, title#10094899, is_redirect#10094900, is_new#10094901, component#10094895L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :              +- *(3) Project [attr#10093503.id AS id#10094898, attr#10093503.title AS title#10094899, attr#10093503.is_redirect AS is_redirect#10094900, attr#10093503.is_new AS is_new#10094901, CASE WHEN isnull(src#10094802L) THEN id#10093512L ELSE src#10094802L END AS component#10094895L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                 +- *(3) BroadcastHashJoin [id#10093512L], [dst#10094698L], LeftOuter, BuildRight
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :- *(3) Project [cast(id#10093447 as bigint) AS id#10093512L, named_struct(id, id#10093447, title, title#10093448, is_redirect, is_redirect#10093449, is_new, is_new#10093450) AS attr#10093503]
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :  +- *(3) BroadcastHashJoin [id#10093447], [id#10093470], Inner, BuildRight
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :     :- *(3) Filter isnotnull(id#10093447)
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :     :  +- *(3) Sample 0.0, 0.05, false, 8258679711852990399
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :     :     +- *(3) FileScan parquet [id#10093447,title#10093448,is_redirect#10093449,is_new#10093450] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/C:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/enwi..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:int,title:string,is_redirect:boolean,is_new:boolean>
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)))
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :        +- *(1) Filter isnotnull(id#10093470)
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :           +- *(1) Sample 0.0, 0.05, false, 8258679711852990399
#    :        :     :        :     :           :     :           :     :           :                    :     :                    :              +- *(1) FileScan parquet [id#10093470] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/C:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/enwi..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:int>
#    :        :     :        :     :           :     :           :     :           :                    :     :                    +- BroadcastExchange HashedRelationBroadcastMode(List(input[1, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :     :                       +- *(2) Filter isnotnull(dst#10094698L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                          +- *(2) InMemoryTableScan [src#10094802L, dst#10094698L], [isnotnull(dst#10094698L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                +- InMemoryRelation [src#10094802L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                      +- *(5) HashAggregate(keys=[src#10094802L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                         +- Exchange hashpartitioning(src#10094802L, dst#10094698L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                            +- *(4) HashAggregate(keys=[src#10094802L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                               +- Union
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :- *(2) Project [min_nbr#10094739L AS src#10094802L, dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :  +- *(2) BroadcastHashJoin [src#10094697L], [src#10094796L], Inner, BuildLeft, NOT (min_nbr#10094739L = dst#10094698L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :  +- *(1) Filter (isnotnull(dst#10094698L) && isnotnull(src#10094697L))
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :     +- *(1) InMemoryTableScan [src#10094697L, dst#10094698L], [isnotnull(dst#10094698L), isnotnull(src#10094697L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :           +- InMemoryRelation [src#10094697L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                 +- *(3) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                    +- Exchange hashpartitioning(src#10094697L, dst#10094698L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                       +- *(2) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                          +- *(2) Project [dst#10094586L AS src#10094697L, min_nbr#10094642L AS dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                             +- *(2) BroadcastHashJoin [src#10094585L], [src#10094626L], Inner, BuildLeft
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                :  +- *(1) Filter isnotnull(src#10094585L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                :     +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L], [isnotnull(src#10094585L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                :           +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                :                 +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                +- *(2) Filter isnotnull(src#10094626L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                   +- *(2) InMemoryTableScan [src#10094626L, min_nbr#10094642L], [isnotnull(src#10094626L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                         +- InMemoryRelation [src#10094626L, min_nbr#10094642L, cnt#10094638L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                               +- *(3) HashAggregate(keys=[src#10094626L], functions=[min(dst#10094627L), count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                                  +- Exchange hashpartitioning(src#10094626L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                                     +- *(2) HashAggregate(keys=[src#10094626L], functions=[partial_min(dst#10094627L), partial_count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                                        +- *(2) Project [_edge#10094624.src AS src#10094626L, _edge#10094624.dst AS dst#10094627L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                                           +- Generate explode(array(named_struct(src, src#10094585L, dst, dst#10094586L), named_struct(src, dst#10094586L, dst, src#10094585L))), false, [_edge#10094624]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                                              +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                                                    +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     :                                                                          +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :     +- *(2) Filter (isnotnull(min_nbr#10094739L) && isnotnull(src#10094796L))
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :        +- *(2) InMemoryTableScan [src#10094796L, min_nbr#10094739L], [isnotnull(min_nbr#10094739L), isnotnull(src#10094796L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :              +- InMemoryRelation [src#10094796L, min_nbr#10094739L, cnt#10094742L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                    +- *(2) HashAggregate(keys=[src#10094697L], functions=[min(dst#10094698L), count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                       +- Exchange hashpartitioning(src#10094697L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                          +- *(1) HashAggregate(keys=[src#10094697L], functions=[partial_min(dst#10094698L), partial_count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                             +- *(1) InMemoryTableScan [src#10094697L, dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                   +- InMemoryRelation [src#10094697L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                         +- *(3) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                            +- Exchange hashpartitioning(src#10094697L, dst#10094698L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                               +- *(2) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                  +- *(2) Project [dst#10094586L AS src#10094697L, min_nbr#10094642L AS dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                     +- *(2) BroadcastHashJoin [src#10094585L], [src#10094626L], Inner, BuildLeft
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                        :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                        :  +- *(1) Filter isnotnull(src#10094585L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                        :     +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L], [isnotnull(src#10094585L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                        :           +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                        :                 +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                        +- *(2) Filter isnotnull(src#10094626L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                           +- *(2) InMemoryTableScan [src#10094626L, min_nbr#10094642L], [isnotnull(src#10094626L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                 +- InMemoryRelation [src#10094626L, min_nbr#10094642L, cnt#10094638L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                       +- *(3) HashAggregate(keys=[src#10094626L], functions=[min(dst#10094627L), count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                          +- Exchange hashpartitioning(src#10094626L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                             +- *(2) HashAggregate(keys=[src#10094626L], functions=[partial_min(dst#10094627L), partial_count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                                +- *(2) Project [_edge#10094624.src AS src#10094626L, _edge#10094624.dst AS dst#10094627L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                                   +- Generate explode(array(named_struct(src, src#10094585L, dst, dst#10094586L), named_struct(src, dst#10094586L, dst, src#10094585L))), false, [_edge#10094624]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                                      +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                                            +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  :                                                                                                  +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                  +- *(3) Project [min_nbr#10094739L AS src#10094805L, src#10094697L AS dst#10094806L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                     +- *(3) InMemoryTableScan [min_nbr#10094739L, src#10094697L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                           +- InMemoryRelation [src#10094697L, min_nbr#10094739L, cnt#10094742L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                 +- *(2) HashAggregate(keys=[src#10094697L], functions=[min(dst#10094698L), count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                    +- Exchange hashpartitioning(src#10094697L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                       +- *(1) HashAggregate(keys=[src#10094697L], functions=[partial_min(dst#10094698L), partial_count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                          +- *(1) InMemoryTableScan [src#10094697L, dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                +- InMemoryRelation [src#10094697L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                      +- *(3) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                         +- Exchange hashpartitioning(src#10094697L, dst#10094698L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                            +- *(2) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                               +- *(2) Project [dst#10094586L AS src#10094697L, min_nbr#10094642L AS dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                  +- *(2) BroadcastHashJoin [src#10094585L], [src#10094626L], Inner, BuildLeft
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                     :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                     :  +- *(1) Filter isnotnull(src#10094585L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                     :     +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L], [isnotnull(src#10094585L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                     :           +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                     :                 +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                     +- *(2) Filter isnotnull(src#10094626L)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                        +- *(2) InMemoryTableScan [src#10094626L, min_nbr#10094642L], [isnotnull(src#10094626L)]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                              +- InMemoryRelation [src#10094626L, min_nbr#10094642L, cnt#10094638L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                    +- *(3) HashAggregate(keys=[src#10094626L], functions=[min(dst#10094627L), count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                       +- Exchange hashpartitioning(src#10094626L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                          +- *(2) HashAggregate(keys=[src#10094626L], functions=[partial_min(dst#10094627L), partial_count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                             +- *(2) Project [_edge#10094624.src AS src#10094626L, _edge#10094624.dst AS dst#10094627L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                                +- Generate explode(array(named_struct(src, src#10094585L, dst, dst#10094586L), named_struct(src, dst#10094586L, dst, src#10094585L))), false, [_edge#10094624]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                                   +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L]
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                                         +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :     :                                                                                                                                               +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#    :        :     :        :     :           :     :           :     :           :                    :     +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :        +- *(3) Filter isnotnull(component#10094952L)
#    :        :     :        :     :           :     :           :     :           :                    :           +- TakeOrderedAndProject(limit=1, orderBy=[count#10094948L DESC NULLS LAST], output=[component#10094952L])
#    :        :     :        :     :           :     :           :     :           :                    :              +- *(2) HashAggregate(keys=[component#10094952L], functions=[count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :                 +- Exchange hashpartitioning(component#10094952L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :                    +- *(1) HashAggregate(keys=[component#10094952L], functions=[partial_count(1)])
#    :        :     :        :     :           :     :           :     :           :                    :                       +- InMemoryTableScan [component#10094952L]
#    :        :     :        :     :           :     :           :     :           :                    :                             +- InMemoryRelation [id#10094898, title#10094899, is_redirect#10094900, is_new#10094901, component#10094952L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :                                   +- *(3) Project [attr#10093503.id AS id#10094898, attr#10093503.title AS title#10094899, attr#10093503.is_redirect AS is_redirect#10094900, attr#10093503.is_new AS is_new#10094901, CASE WHEN isnull(src#10094802L) THEN id#10093512L ELSE src#10094802L END AS component#10094895L]
#    :        :     :        :     :           :     :           :     :           :                    :                                      +- *(3) BroadcastHashJoin [id#10093512L], [dst#10094698L], LeftOuter, BuildRight
#    :        :     :        :     :           :     :           :     :           :                    :                                         :- *(3) Project [cast(id#10093447 as bigint) AS id#10093512L, named_struct(id, id#10093447, title, title#10093448, is_redirect, is_redirect#10093449, is_new, is_new#10093450) AS attr#10093503]
#    :        :     :        :     :           :     :           :     :           :                    :                                         :  +- *(3) BroadcastHashJoin [id#10093447], [id#10093470], Inner, BuildRight
#    :        :     :        :     :           :     :           :     :           :                    :                                         :     :- *(3) Filter isnotnull(id#10093447)
#    :        :     :        :     :           :     :           :     :           :                    :                                         :     :  +- *(3) Sample 0.0, 0.05, false, 8258679711852990399
#    :        :     :        :     :           :     :           :     :           :                    :                                         :     :     +- *(3) FileScan parquet [id#10093447,title#10093448,is_redirect#10093449,is_new#10093450] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/C:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/enwi..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:int,title:string,is_redirect:boolean,is_new:boolean>
#    :        :     :        :     :           :     :           :     :           :                    :                                         :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)))
#    :        :     :        :     :           :     :           :     :           :                    :                                         :        +- *(1) Filter isnotnull(id#10093470)
#    :        :     :        :     :           :     :           :     :           :                    :                                         :           +- *(1) Sample 0.0, 0.05, false, 8258679711852990399
#    :        :     :        :     :           :     :           :     :           :                    :                                         :              +- *(1) FileScan parquet [id#10093470] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/C:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/enwi..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:int>
#    :        :     :        :     :           :     :           :     :           :                    :                                         +- BroadcastExchange HashedRelationBroadcastMode(List(input[1, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :                                            +- *(2) Filter isnotnull(dst#10094698L)
#    :        :     :        :     :           :     :           :     :           :                    :                                               +- *(2) InMemoryTableScan [src#10094802L, dst#10094698L], [isnotnull(dst#10094698L)]
#    :        :     :        :     :           :     :           :     :           :                    :                                                     +- InMemoryRelation [src#10094802L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :                                                           +- *(5) HashAggregate(keys=[src#10094802L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :                                                              +- Exchange hashpartitioning(src#10094802L, dst#10094698L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :                                                                 +- *(4) HashAggregate(keys=[src#10094802L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :                                                                    +- Union
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :- *(2) Project [min_nbr#10094739L AS src#10094802L, dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :  +- *(2) BroadcastHashJoin [src#10094697L], [src#10094796L], Inner, BuildLeft, NOT (min_nbr#10094739L = dst#10094698L)
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :  +- *(1) Filter (isnotnull(dst#10094698L) && isnotnull(src#10094697L))
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :     +- *(1) InMemoryTableScan [src#10094697L, dst#10094698L], [isnotnull(dst#10094698L), isnotnull(src#10094697L)]
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :           +- InMemoryRelation [src#10094697L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                 +- *(3) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                    +- Exchange hashpartitioning(src#10094697L, dst#10094698L, 16)
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                       +- *(2) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                          +- *(2) Project [dst#10094586L AS src#10094697L, min_nbr#10094642L AS dst#10094698L]
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                             +- *(2) BroadcastHashJoin [src#10094585L], [src#10094626L], Inner, BuildLeft
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                                :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                                :  +- *(1) Filter isnotnull(src#10094585L)
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                                :     +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L], [isnotnull(src#10094585L)]
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                                :           +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#    :        :     :        :     :           :     :           :     :           :                    :                                                                       :     :                                :                 +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
# ...
#                :           :                                            :                                                  :                       +- Exchange hashpartitioning(src#10094697L, 16)
#                :           :                                            :                                                  :                          +- *(1) HashAggregate(keys=[src#10094697L], functions=[partial_min(dst#10094698L), partial_count(1)])
#                :           :                                            :                                                  :                             +- *(1) InMemoryTableScan [src#10094697L, dst#10094698L]
#                :           :                                            :                                                  :                                   +- InMemoryRelation [src#10094697L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                  :                                         +- *(3) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#                :           :                                            :                                                  :                                            +- Exchange hashpartitioning(src#10094697L, dst#10094698L, 16)
#                :           :                                            :                                                  :                                               +- *(2) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#                :           :                                            :                                                  :                                                  +- *(2) Project [dst#10094586L AS src#10094697L, min_nbr#10094642L AS dst#10094698L]
#                :           :                                            :                                                  :                                                     +- *(2) BroadcastHashJoin [src#10094585L], [src#10094626L], Inner, BuildLeft
#                :           :                                            :                                                  :                                                        :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#                :           :                                            :                                                  :                                                        :  +- *(1) Filter isnotnull(src#10094585L)
#                :           :                                            :                                                  :                                                        :     +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L], [isnotnull(src#10094585L)]
#                :           :                                            :                                                  :                                                        :           +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                  :                                                        :                 +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#                :           :                                            :                                                  :                                                        +- *(2) Filter isnotnull(src#10094626L)
#                :           :                                            :                                                  :                                                           +- *(2) InMemoryTableScan [src#10094626L, min_nbr#10094642L], [isnotnull(src#10094626L)]
#                :           :                                            :                                                  :                                                                 +- InMemoryRelation [src#10094626L, min_nbr#10094642L, cnt#10094638L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                  :                                                                       +- *(3) HashAggregate(keys=[src#10094626L], functions=[min(dst#10094627L), count(1)])
#                :           :                                            :                                                  :                                                                          +- Exchange hashpartitioning(src#10094626L, 16)
#                :           :                                            :                                                  :                                                                             +- *(2) HashAggregate(keys=[src#10094626L], functions=[partial_min(dst#10094627L), partial_count(1)])
#                :           :                                            :                                                  :                                                                                +- *(2) Project [_edge#10094624.src AS src#10094626L, _edge#10094624.dst AS dst#10094627L]
#                :           :                                            :                                                  :                                                                                   +- Generate explode(array(named_struct(src, src#10094585L, dst, dst#10094586L), named_struct(src, dst#10094586L, dst, src#10094585L))), false, [_edge#10094624]
#                :           :                                            :                                                  :                                                                                      +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L]
#                :           :                                            :                                                  :                                                                                            +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                  :                                                                                                  +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#                :           :                                            :                                                  +- *(3) Project [min_nbr#10094739L AS src#10094805L, src#10094697L AS dst#10094806L]
#                :           :                                            :                                                     +- *(3) InMemoryTableScan [min_nbr#10094739L, src#10094697L]
#                :           :                                            :                                                           +- InMemoryRelation [src#10094697L, min_nbr#10094739L, cnt#10094742L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                                 +- *(2) HashAggregate(keys=[src#10094697L], functions=[min(dst#10094698L), count(1)])
#                :           :                                            :                                                                    +- Exchange hashpartitioning(src#10094697L, 16)
#                :           :                                            :                                                                       +- *(1) HashAggregate(keys=[src#10094697L], functions=[partial_min(dst#10094698L), partial_count(1)])
#                :           :                                            :                                                                          +- *(1) InMemoryTableScan [src#10094697L, dst#10094698L]
#                :           :                                            :                                                                                +- InMemoryRelation [src#10094697L, dst#10094698L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                                                      +- *(3) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#                :           :                                            :                                                                                         +- Exchange hashpartitioning(src#10094697L, dst#10094698L, 16)
#                :           :                                            :                                                                                            +- *(2) HashAggregate(keys=[src#10094697L, dst#10094698L], functions=[])
#                :           :                                            :                                                                                               +- *(2) Project [dst#10094586L AS src#10094697L, min_nbr#10094642L AS dst#10094698L]
#                :           :                                            :                                                                                                  +- *(2) BroadcastHashJoin [src#10094585L], [src#10094626L], Inner, BuildLeft
#                :           :                                            :                                                                                                     :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#                :           :                                            :                                                                                                     :  +- *(1) Filter isnotnull(src#10094585L)
#                :           :                                            :                                                                                                     :     +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L], [isnotnull(src#10094585L)]
#                :           :                                            :                                                                                                     :           +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                                                                     :                 +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#                :           :                                            :                                                                                                     +- *(2) Filter isnotnull(src#10094626L)
#                :           :                                            :                                                                                                        +- *(2) InMemoryTableScan [src#10094626L, min_nbr#10094642L], [isnotnull(src#10094626L)]
#                :           :                                            :                                                                                                              +- InMemoryRelation [src#10094626L, min_nbr#10094642L, cnt#10094638L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                                                                                    +- *(3) HashAggregate(keys=[src#10094626L], functions=[min(dst#10094627L), count(1)])
#                :           :                                            :                                                                                                                       +- Exchange hashpartitioning(src#10094626L, 16)
#                :           :                                            :                                                                                                                          +- *(2) HashAggregate(keys=[src#10094626L], functions=[partial_min(dst#10094627L), partial_count(1)])
#                :           :                                            :                                                                                                                             +- *(2) Project [_edge#10094624.src AS src#10094626L, _edge#10094624.dst AS dst#10094627L]
#                :           :                                            :                                                                                                                                +- Generate explode(array(named_struct(src, src#10094585L, dst, dst#10094586L), named_struct(src, dst#10094586L, dst, src#10094585L))), false, [_edge#10094624]
#                :           :                                            :                                                                                                                                   +- *(1) InMemoryTableScan [src#10094585L, dst#10094586L]
#                :           :                                            :                                                                                                                                         +- InMemoryRelation [src#10094585L, dst#10094586L], StorageLevel(disk, memory, deserialized, 1 replicas)
#                :           :                                            :                                                                                                                                               +- *(1) FileScan parquet [src#10094585L,dst#10094586L] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/tmp/dad..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<src:bigint,dst:bigint>
#                :           :                                            +- ReusedExchange [component#10094952L], BroadcastExchange HashedRelationBroadcastMode(List(input[0, bigint, false]))
#                :           +- ReusedExchange [id#10170162, rank#10170159], BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)))
#                +- *(3970) Sort [id#10170223L ASC NULLS FIRST], false, 0
#                   +- Exchange hashpartitioning(id#10170223L, 16)
#                      +- *(3969) Project [id#10170223L]
#                         +- *(3969) Filter isnotnull(id#10170223L)
#                            +- FlatMapGroupsInPandas [part#10170215], compute_fiedler(src#10170201, dst#10170202, part#10170215), [id#10170223L, value#10170224]
#                               +- *(3968) Sort [part#10170215 ASC NULLS FIRST], false, 0
#                                  +- ReusedExchange [part#10170215, src#10170201, dst#10170202, part#10170215], Exchange hashpartitioning(part#10170215, 16)

# %%
g = sample_graph(pages, pagelinks, 0.5)
g.cache()
result = recursive_bipartition(g, max_iter=4)
signs = [c for c in result.columns if c.startswith("sign_")]
# %time result.groupBy(signs).count().show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <timed eval> in <module>()
#
# ~\Anaconda3\lib\site-packages\pyspark\sql\dataframe.py in show(self, n, truncate, vertical)
#     378         """
#     379         if isinstance(truncate, bool) and truncate:
# --> 380             print(self._jdf.showString(n, 20, vertical))
#     381         else:
#     382             print(self._jdf.showString(n, int(truncate), vertical))
#
# ~\Anaconda3\lib\site-packages\pyspark\python\lib\py4j-0.10.7-src.zip\py4j\java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ~\Anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# ~\Anaconda3\lib\site-packages\pyspark\python\lib\py4j-0.10.7-src.zip\py4j\protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o4076.showString.
# : org.apache.spark.sql.catalyst.errors.package$TreeNodeException: makeCopy, tree:
# Project [id#833218, (rank#833211 - 1) AS rank#833215]
# +- Filter (isnotnull(id#833218) && isnotnull((rank#833211 - 1)))
#    +- Window [row_number() windowspecdefinition(id#833218 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank#833211], [id#833218 ASC NULLS FIRST]
#       +- *(788811) Sort [id#833218 ASC NULLS FIRST], false, 0
#          +- Exchange SinglePartition
#             +- InMemoryTableScan [id#833218]
#                   +- InMemoryRelation [id#833218, title#45, is_redirect#46, is_new#47, original_id#833149], StorageLevel(disk, memory, deserialized, 1 replicas)
#                         +- *(7) Project [rank#833122 AS id#833156, title#45, is_redirect#46, is_new#47, id#44 AS original_id#833149]
#                            +- *(7) SortMergeJoin [id#44], [id#833125], Inner
#                               :- *(2) Sort [id#44 ASC NULLS FIRST], false, 0
#                               :  +- Exchange hashpartitioning(id#44, 16)
#                               :     +- *(1) Filter isnotnull(id#44)
#                               :        +- *(1) Sample 0.0, 0.5, false, 8569580320832862874
#                               :           +- *(1) FileScan parquet [id#44,title#45,is_redirect#46,is_new#47] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/C:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/enwi..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:int,title:string,is_redirect:boolean,is_new:boolean>
#                               +- *(6) Sort [id#833125 ASC NULLS FIRST], false, 0
#                                  +- Exchange hashpartitioning(id#833125, 16)
#                                     +- *(5) Project [id#833125, (rank#833118 - 1) AS rank#833122]
#                                        +- *(5) Filter isnotnull(id#833125)
#                                           +- Window [row_number() windowspecdefinition(id#833125 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank#833118], [id#833125 ASC NULLS FIRST]
#                                              +- *(4) Sort [id#833125 ASC NULLS FIRST], false, 0
#                                                 +- Exchange SinglePartition
#                                                    +- *(3) Sample 0.0, 0.5, false, 8569580320832862874
#                                                       +- *(3) FileScan parquet [id#833125] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/C:/Users/acmiy/OneDrive/Documents/cs229/cs229-f19-wiki-forecast/data/enwi..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:int>
#
# 	at org.apache.spark.sql.catalyst.errors.package$.attachTree(package.scala:56)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.makeCopy(TreeNode.scala:380)
# 	at org.apache.spark.sql.execution.SparkPlan.makeCopy(SparkPlan.scala:73)
# 	at org.apache.spark.sql.execution.SparkPlan.makeCopy(SparkPlan.scala:47)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:361)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# ...
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# Caused by: java.lang.OutOfMemoryError: GC overhead limit exceeded
# 	at scala.collection.mutable.ResizableArray$class.$init$(ResizableArray.scala:32)
# 	at scala.collection.mutable.ArrayBuffer.<init>(ArrayBuffer.scala:49)
# 	at scala.collection.mutable.ArrayBuffer.<init>(ArrayBuffer.scala:63)
# 	at org.apache.spark.sql.execution.SparkPlan.<init>(SparkPlan.scala:164)
# 	at org.apache.spark.sql.execution.ProjectExec.<init>(basicPhysicalOperators.scala:36)
# 	at sun.reflect.GeneratedConstructorAccessor131.newInstance(Unknown Source)
# 	at sun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:423)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$makeCopy$1$$anonfun$apply$15.apply(TreeNode.scala:406)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$makeCopy$1$$anonfun$apply$15.apply(TreeNode.scala:406)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:70)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$makeCopy$1.apply(TreeNode.scala:405)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$makeCopy$1.apply(TreeNode.scala:380)
# 	at org.apache.spark.sql.catalyst.errors.package$.attachTree(package.scala:52)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.makeCopy(TreeNode.scala:380)
# 	at org.apache.spark.sql.execution.SparkPlan.makeCopy(SparkPlan.scala:73)
# 	at org.apache.spark.sql.execution.SparkPlan.makeCopy(SparkPlan.scala:47)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:361)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$3.apply(TreeNode.scala:278)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$4.apply(TreeNode.scala:329)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapProductIterator(TreeNode.scala:187)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.mapChildren(TreeNode.scala:327)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:278)
# 	... 1 more
