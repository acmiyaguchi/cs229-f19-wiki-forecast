# %% [markdown]
# ## Spark ML Pipeline for Wikipedia Traffic Forecasting
#
# In this notebook, we construct the entire pipeline for learning a generalized linear model and a neural network.

# %%
from pyspark.sql import functions as F, types as T

# %%
pagecount = spark.read.parquet("../data/enwiki/pagecount_daily_v2")
pages = spark.read.parquet("../data/enwiki/pages")
pagelinks = spark.read.parquet("../data/enwiki/pagelinks")

# %%
pagecount.count()
# Out:
# 87420272

# %%
pagecount.show(vertical=True, n=2)
# Out:
# -RECORD 0-------------
#  page_id | 1436
#  date    | 2018-06-27
#  count   | 1154
# -RECORD 1-------------
#  page_id | 1436
#  date    | 2018-11-08
#  count   | 1598
# only showing top 2 rows

# %% [markdown]
# ### Creating and caching the main view
#
# We create a time-series vector for each page. We cache it since it will be reused several times in this session.

# %%
dataset = pagecount.groupBy("page_id").pivot("date").agg(F.min("count"))
dataset.cache()
dataset.printSchema(), dataset.count()
# Out:
# root
#  |-- page_id: long (nullable = true)
#  |-- 2018-01-01: long (nullable = true)
#  |-- 2018-01-02: long (nullable = true)
#  |-- 2018-01-03: long (nullable = true)
#  |-- 2018-01-04: long (nullable = true)
#  |-- 2018-01-05: long (nullable = true)
#  |-- 2018-01-06: long (nullable = true)
#  |-- 2018-01-07: long (nullable = true)
#  |-- 2018-01-08: long (nullable = true)
#  |-- 2018-01-09: long (nullable = true)
#  |-- 2018-01-10: long (nullable = true)
#  |-- 2018-01-11: long (nullable = true)
#  |-- 2018-01-12: long (nullable = true)
#  |-- 2018-01-13: long (nullable = true)
#  |-- 2018-01-14: long (nullable = true)
#  |-- 2018-01-15: long (nullable = true)
#  |-- 2018-01-16: long (nullable = true)
#  |-- 2018-01-17: long (nullable = true)
#  |-- 2018-01-18: long (nullable = true)
#  |-- 2018-01-19: long (nullable = true)
#  |-- 2018-01-20: long (nullable = true)
#  |-- 2018-01-21: long (nullable = true)
#  |-- 2018-01-22: long (nullable = true)
#  |-- 2018-01-23: long (nullable = true)
#  |-- 2018-01-24: long (nullable = true)
#  |-- 2018-01-25: long (nullable = true)
#  |-- 2018-01-26: long (nullable = true)
#  |-- 2018-01-27: long (nullable = true)
#  |-- 2018-01-28: long (nullable = true)
#  |-- 2018-01-29: long (nullable = true)
#  |-- 2018-01-30: long (nullable = true)
#  |-- 2018-01-31: long (nullable = true)
#  |-- 2018-02-01: long (nullable = true)
#  |-- 2018-02-02: long (nullable = true)
#  |-- 2018-02-03: long (nullable = true)
#  |-- 2018-02-04: long (nullable = true)
#  |-- 2018-02-05: long (nullable = true)
#  |-- 2018-02-06: long (nullable = true)
#  |-- 2018-02-07: long (nullable = true)
#  |-- 2018-02-08: long (nullable = true)
#  |-- 2018-02-09: long (nullable = true)
#  |-- 2018-02-10: long (nullable = true)
#  |-- 2018-02-11: long (nullable = true)
#  |-- 2018-02-12: long (nullable = true)
#  |-- 2018-02-13: long (nullable = true)
#  |-- 2018-02-14: long (nullable = true)
#  |-- 2018-02-15: long (nullable = true)
#  |-- 2018-02-16: long (nullable = true)
#  |-- 2018-02-17: long (nullable = true)
#  |-- 2018-02-18: long (nullable = true)
#  |-- 2018-02-19: long (nullable = true)
#  |-- 2018-02-20: long (nullable = true)
#  |-- 2018-02-21: long (nullable = true)
#  |-- 2018-02-22: long (nullable = true)
#  |-- 2018-02-23: long (nullable = true)
#  |-- 2018-02-24: long (nullable = true)
#  |-- 2018-02-25: long (nullable = true)
#  |-- 2018-02-26: long (nullable = true)
#  |-- 2018-02-27: long (nullable = true)
#  |-- 2018-02-28: long (nullable = true)
#  |-- 2018-03-01: long (nullable = true)
#  |-- 2018-03-02: long (nullable = true)
#  |-- 2018-03-03: long (nullable = true)
#  |-- 2018-03-04: long (nullable = true)
#  |-- 2018-03-05: long (nullable = true)
#  |-- 2018-03-06: long (nullable = true)
#  |-- 2018-03-07: long (nullable = true)
#  |-- 2018-03-08: long (nullable = true)
#  |-- 2018-03-09: long (nullable = true)
#  |-- 2018-03-10: long (nullable = true)
#  |-- 2018-03-11: long (nullable = true)
#  |-- 2018-03-12: long (nullable = true)
#  |-- 2018-03-13: long (nullable = true)
#  |-- 2018-03-14: long (nullable = true)
#  |-- 2018-03-15: long (nullable = true)
#  |-- 2018-03-16: long (nullable = true)
#  |-- 2018-03-17: long (nullable = true)
#  |-- 2018-03-18: long (nullable = true)
#  |-- 2018-03-19: long (nullable = true)
#  |-- 2018-03-20: long (nullable = true)
#  |-- 2018-03-21: long (nullable = true)
#  |-- 2018-03-22: long (nullable = true)
#  |-- 2018-03-23: long (nullable = true)
#  |-- 2018-03-24: long (nullable = true)
#  |-- 2018-03-25: long (nullable = true)
#  |-- 2018-03-26: long (nullable = true)
#  |-- 2018-03-27: long (nullable = true)
#  |-- 2018-03-28: long (nullable = true)
#  |-- 2018-03-29: long (nullable = true)
#  |-- 2018-03-30: long (nullable = true)
#  |-- 2018-03-31: long (nullable = true)
#  |-- 2018-04-01: long (nullable = true)
#  |-- 2018-04-02: long (nullable = true)
#  |-- 2018-04-03: long (nullable = true)
#  |-- 2018-04-04: long (nullable = true)
#  |-- 2018-04-05: long (nullable = true)
#  |-- 2018-04-06: long (nullable = true)
#  |-- 2018-04-07: long (nullable = true)
#  |-- 2018-04-08: long (nullable = true)
#  |-- 2018-04-09: long (nullable = true)
#  |-- 2018-04-10: long (nullable = true)
#  |-- 2018-04-11: long (nullable = true)
#  |-- 2018-04-12: long (nullable = true)
#  |-- 2018-04-13: long (nullable = true)
#  |-- 2018-04-14: long (nullable = true)
#  |-- 2018-04-15: long (nullable = true)
#  |-- 2018-04-16: long (nullable = true)
#  |-- 2018-04-17: long (nullable = true)
#  |-- 2018-04-18: long (nullable = true)
#  |-- 2018-04-19: long (nullable = true)
#  |-- 2018-04-20: long (nullable = true)
#  |-- 2018-04-21: long (nullable = true)
#  |-- 2018-04-22: long (nullable = true)
#  |-- 2018-04-23: long (nullable = true)
#  |-- 2018-04-24: long (nullable = true)
#  |-- 2018-04-25: long (nullable = true)
#  |-- 2018-04-26: long (nullable = true)
#  |-- 2018-04-27: long (nullable = true)
#  |-- 2018-04-28: long (nullable = true)
#  |-- 2018-04-29: long (nullable = true)
#  |-- 2018-04-30: long (nullable = true)
#  |-- 2018-05-01: long (nullable = true)
#  |-- 2018-05-02: long (nullable = true)
#  |-- 2018-05-03: long (nullable = true)
#  |-- 2018-05-04: long (nullable = true)
#  |-- 2018-05-05: long (nullable = true)
#  |-- 2018-05-06: long (nullable = true)
#  |-- 2018-05-07: long (nullable = true)
#  |-- 2018-05-08: long (nullable = true)
#  |-- 2018-05-09: long (nullable = true)
#  |-- 2018-05-10: long (nullable = true)
#  |-- 2018-05-11: long (nullable = true)
#  |-- 2018-05-12: long (nullable = true)
#  |-- 2018-05-13: long (nullable = true)
#  |-- 2018-05-14: long (nullable = true)
#  |-- 2018-05-15: long (nullable = true)
#  |-- 2018-05-16: long (nullable = true)
#  |-- 2018-05-17: long (nullable = true)
#  |-- 2018-05-18: long (nullable = true)
#  |-- 2018-05-19: long (nullable = true)
#  |-- 2018-05-20: long (nullable = true)
#  |-- 2018-05-21: long (nullable = true)
#  |-- 2018-05-22: long (nullable = true)
#  |-- 2018-05-23: long (nullable = true)
#  |-- 2018-05-24: long (nullable = true)
#  |-- 2018-05-25: long (nullable = true)
#  |-- 2018-05-26: long (nullable = true)
#  |-- 2018-05-27: long (nullable = true)
#  |-- 2018-05-28: long (nullable = true)
#  |-- 2018-05-29: long (nullable = true)
#  |-- 2018-05-30: long (nullable = true)
#  |-- 2018-05-31: long (nullable = true)
#  |-- 2018-06-01: long (nullable = true)
#  |-- 2018-06-02: long (nullable = true)
#  |-- 2018-06-03: long (nullable = true)
#  |-- 2018-06-04: long (nullable = true)
#  |-- 2018-06-05: long (nullable = true)
#  |-- 2018-06-06: long (nullable = true)
#  |-- 2018-06-07: long (nullable = true)
#  |-- 2018-06-08: long (nullable = true)
#  |-- 2018-06-09: long (nullable = true)
#  |-- 2018-06-10: long (nullable = true)
#  |-- 2018-06-11: long (nullable = true)
#  |-- 2018-06-12: long (nullable = true)
#  |-- 2018-06-13: long (nullable = true)
#  |-- 2018-06-15: long (nullable = true)
#  |-- 2018-06-16: long (nullable = true)
#  |-- 2018-06-17: long (nullable = true)
#  |-- 2018-06-18: long (nullable = true)
#  |-- 2018-06-19: long (nullable = true)
#  |-- 2018-06-20: long (nullable = true)
#  |-- 2018-06-21: long (nullable = true)
#  |-- 2018-06-22: long (nullable = true)
#  |-- 2018-06-23: long (nullable = true)
#  |-- 2018-06-24: long (nullable = true)
#  |-- 2018-06-25: long (nullable = true)
#  |-- 2018-06-26: long (nullable = true)
#  |-- 2018-06-27: long (nullable = true)
#  |-- 2018-06-28: long (nullable = true)
#  |-- 2018-06-29: long (nullable = true)
#  |-- 2018-06-30: long (nullable = true)
#  |-- 2018-07-01: long (nullable = true)
#  |-- 2018-07-02: long (nullable = true)
#  |-- 2018-07-03: long (nullable = true)
#  |-- 2018-07-04: long (nullable = true)
#  |-- 2018-07-05: long (nullable = true)
#  |-- 2018-07-06: long (nullable = true)
#  |-- 2018-07-07: long (nullable = true)
#  |-- 2018-07-08: long (nullable = true)
#  |-- 2018-07-09: long (nullable = true)
#  |-- 2018-07-10: long (nullable = true)
#  |-- 2018-07-11: long (nullable = true)
#  |-- 2018-07-12: long (nullable = true)
#  |-- 2018-07-13: long (nullable = true)
#  |-- 2018-07-14: long (nullable = true)
#  |-- 2018-07-15: long (nullable = true)
#  |-- 2018-07-16: long (nullable = true)
#  |-- 2018-07-17: long (nullable = true)
#  |-- 2018-07-18: long (nullable = true)
#  |-- 2018-07-19: long (nullable = true)
#  |-- 2018-07-20: long (nullable = true)
#  |-- 2018-07-21: long (nullable = true)
#  |-- 2018-07-22: long (nullable = true)
#  |-- 2018-07-23: long (nullable = true)
#  |-- 2018-07-24: long (nullable = true)
#  |-- 2018-07-25: long (nullable = true)
#  |-- 2018-07-26: long (nullable = true)
#  |-- 2018-07-27: long (nullable = true)
#  |-- 2018-07-28: long (nullable = true)
#  |-- 2018-07-29: long (nullable = true)
#  |-- 2018-07-30: long (nullable = true)
#  |-- 2018-07-31: long (nullable = true)
#  |-- 2018-08-01: long (nullable = true)
#  |-- 2018-08-02: long (nullable = true)
#  |-- 2018-08-03: long (nullable = true)
#  |-- 2018-08-04: long (nullable = true)
#  |-- 2018-08-05: long (nullable = true)
#  |-- 2018-08-06: long (nullable = true)
#  |-- 2018-08-07: long (nullable = true)
#  |-- 2018-08-08: long (nullable = true)
#  |-- 2018-08-09: long (nullable = true)
#  |-- 2018-08-10: long (nullable = true)
#  |-- 2018-08-11: long (nullable = true)
#  |-- 2018-08-12: long (nullable = true)
#  |-- 2018-08-13: long (nullable = true)
#  |-- 2018-08-14: long (nullable = true)
#  |-- 2018-08-15: long (nullable = true)
#  |-- 2018-08-16: long (nullable = true)
#  |-- 2018-08-17: long (nullable = true)
#  |-- 2018-08-18: long (nullable = true)
#  |-- 2018-08-19: long (nullable = true)
#  |-- 2018-08-20: long (nullable = true)
#  |-- 2018-08-21: long (nullable = true)
#  |-- 2018-08-22: long (nullable = true)
#  |-- 2018-08-23: long (nullable = true)
#  |-- 2018-08-24: long (nullable = true)
#  |-- 2018-08-25: long (nullable = true)
#  |-- 2018-08-26: long (nullable = true)
#  |-- 2018-08-27: long (nullable = true)
#  |-- 2018-08-28: long (nullable = true)
#  |-- 2018-08-29: long (nullable = true)
#  |-- 2018-08-30: long (nullable = true)
#  |-- 2018-08-31: long (nullable = true)
#  |-- 2018-09-01: long (nullable = true)
#  |-- 2018-09-02: long (nullable = true)
#  |-- 2018-09-03: long (nullable = true)
#  |-- 2018-09-04: long (nullable = true)
#  |-- 2018-09-05: long (nullable = true)
#  |-- 2018-09-06: long (nullable = true)
#  |-- 2018-09-07: long (nullable = true)
#  |-- 2018-09-08: long (nullable = true)
#  |-- 2018-09-09: long (nullable = true)
#  |-- 2018-09-10: long (nullable = true)
#  |-- 2018-09-11: long (nullable = true)
#  |-- 2018-09-12: long (nullable = true)
#  |-- 2018-09-13: long (nullable = true)
#  |-- 2018-09-14: long (nullable = true)
#  |-- 2018-09-15: long (nullable = true)
#  |-- 2018-09-16: long (nullable = true)
#  |-- 2018-09-17: long (nullable = true)
#  |-- 2018-09-18: long (nullable = true)
#  |-- 2018-09-19: long (nullable = true)
#  |-- 2018-09-20: long (nullable = true)
#  |-- 2018-09-21: long (nullable = true)
#  |-- 2018-09-22: long (nullable = true)
#  |-- 2018-09-23: long (nullable = true)
#  |-- 2018-09-24: long (nullable = true)
#  |-- 2018-09-25: long (nullable = true)
#  |-- 2018-09-26: long (nullable = true)
#  |-- 2018-09-27: long (nullable = true)
#  |-- 2018-09-28: long (nullable = true)
#  |-- 2018-09-29: long (nullable = true)
#  |-- 2018-09-30: long (nullable = true)
#  |-- 2018-10-01: long (nullable = true)
#  |-- 2018-10-02: long (nullable = true)
#  |-- 2018-10-03: long (nullable = true)
#  |-- 2018-10-04: long (nullable = true)
#  |-- 2018-10-05: long (nullable = true)
#  |-- 2018-10-06: long (nullable = true)
#  |-- 2018-10-07: long (nullable = true)
#  |-- 2018-10-08: long (nullable = true)
#  |-- 2018-10-09: long (nullable = true)
#  |-- 2018-10-10: long (nullable = true)
#  |-- 2018-10-11: long (nullable = true)
#  |-- 2018-10-12: long (nullable = true)
#  |-- 2018-10-13: long (nullable = true)
#  |-- 2018-10-14: long (nullable = true)
#  |-- 2018-10-15: long (nullable = true)
#  |-- 2018-10-16: long (nullable = true)
#  |-- 2018-10-17: long (nullable = true)
#  |-- 2018-10-18: long (nullable = true)
#  |-- 2018-10-19: long (nullable = true)
#  |-- 2018-10-20: long (nullable = true)
#  |-- 2018-10-21: long (nullable = true)
#  |-- 2018-10-22: long (nullable = true)
#  |-- 2018-10-23: long (nullable = true)
#  |-- 2018-10-24: long (nullable = true)
#  |-- 2018-10-25: long (nullable = true)
#  |-- 2018-10-26: long (nullable = true)
#  |-- 2018-10-27: long (nullable = true)
#  |-- 2018-10-28: long (nullable = true)
#  |-- 2018-10-29: long (nullable = true)
#  |-- 2018-10-30: long (nullable = true)
#  |-- 2018-10-31: long (nullable = true)
#  |-- 2018-11-01: long (nullable = true)
#  |-- 2018-11-02: long (nullable = true)
#  |-- 2018-11-03: long (nullable = true)
#  |-- 2018-11-04: long (nullable = true)
#  |-- 2018-11-05: long (nullable = true)
#  |-- 2018-11-06: long (nullable = true)
#  |-- 2018-11-07: long (nullable = true)
#  |-- 2018-11-08: long (nullable = true)
#  |-- 2018-11-09: long (nullable = true)
#  |-- 2018-11-10: long (nullable = true)
#  |-- 2018-11-11: long (nullable = true)
#  |-- 2018-11-12: long (nullable = true)
#  |-- 2018-11-13: long (nullable = true)
#  |-- 2018-11-14: long (nullable = true)
#  |-- 2018-11-15: long (nullable = true)
#  |-- 2018-11-16: long (nullable = true)
#  |-- 2018-11-17: long (nullable = true)
#  |-- 2018-11-18: long (nullable = true)
#  |-- 2018-11-19: long (nullable = true)
#  |-- 2018-11-20: long (nullable = true)
#  |-- 2018-11-21: long (nullable = true)
#  |-- 2018-11-22: long (nullable = true)
#  |-- 2018-11-23: long (nullable = true)
#  |-- 2018-11-24: long (nullable = true)
#  |-- 2018-11-25: long (nullable = true)
#  |-- 2018-11-26: long (nullable = true)
#  |-- 2018-11-27: long (nullable = true)
#  |-- 2018-11-28: long (nullable = true)
#  |-- 2018-11-29: long (nullable = true)
#  |-- 2018-11-30: long (nullable = true)
#  |-- 2018-12-01: long (nullable = true)
#  |-- 2018-12-02: long (nullable = true)
#  |-- 2018-12-03: long (nullable = true)
#  |-- 2018-12-04: long (nullable = true)
#  |-- 2018-12-05: long (nullable = true)
#  |-- 2018-12-06: long (nullable = true)
#  |-- 2018-12-07: long (nullable = true)
#  |-- 2018-12-08: long (nullable = true)
#  |-- 2018-12-09: long (nullable = true)
#  |-- 2018-12-10: long (nullable = true)
#  |-- 2018-12-11: long (nullable = true)
#  |-- 2018-12-12: long (nullable = true)
#  |-- 2018-12-13: long (nullable = true)
#  |-- 2018-12-14: long (nullable = true)
#  |-- 2018-12-15: long (nullable = true)
#  |-- 2018-12-16: long (nullable = true)
#  |-- 2018-12-17: long (nullable = true)
#  |-- 2018-12-18: long (nullable = true)
#  |-- 2018-12-19: long (nullable = true)
#  |-- 2018-12-20: long (nullable = true)
#  |-- 2018-12-21: long (nullable = true)
#  |-- 2018-12-22: long (nullable = true)
#  |-- 2018-12-23: long (nullable = true)
#  |-- 2018-12-24: long (nullable = true)
#  |-- 2018-12-25: long (nullable = true)
#  |-- 2018-12-26: long (nullable = true)
#  |-- 2018-12-27: long (nullable = true)
#  |-- 2018-12-28: long (nullable = true)
#  |-- 2018-12-29: long (nullable = true)
#  |-- 2018-12-30: long (nullable = true)
#  |-- 2018-12-31: long (nullable = true)
#  |-- 2019-01-01: long (nullable = true)
#  |-- 2019-01-02: long (nullable = true)
#  |-- 2019-01-03: long (nullable = true)
#  |-- 2019-01-04: long (nullable = true)
#  |-- 2019-01-05: long (nullable = true)
#  |-- 2019-01-06: long (nullable = true)
#  |-- 2019-01-07: long (nullable = true)
#  |-- 2019-01-08: long (nullable = true)
#  |-- 2019-01-09: long (nullable = true)
#  |-- 2019-01-10: long (nullable = true)
#  |-- 2019-01-11: long (nullable = true)
#  |-- 2019-01-12: long (nullable = true)
#  |-- 2019-01-13: long (nullable = true)
#  |-- 2019-01-14: long (nullable = true)
#  |-- 2019-01-15: long (nullable = true)
#  |-- 2019-01-16: long (nullable = true)
#  |-- 2019-01-17: long (nullable = true)
#  |-- 2019-01-18: long (nullable = true)
#  |-- 2019-01-19: long (nullable = true)
#  |-- 2019-01-20: long (nullable = true)
#  |-- 2019-01-21: long (nullable = true)
#  |-- 2019-01-22: long (nullable = true)
#  |-- 2019-01-23: long (nullable = true)
#  |-- 2019-01-24: long (nullable = true)
#  |-- 2019-01-25: long (nullable = true)
#  |-- 2019-01-26: long (nullable = true)
#  |-- 2019-01-27: long (nullable = true)
#  |-- 2019-01-28: long (nullable = true)
#  |-- 2019-01-29: long (nullable = true)
#  |-- 2019-01-30: long (nullable = true)
#  |-- 2019-01-31: long (nullable = true)
#  |-- 2019-02-01: long (nullable = true)
#  |-- 2019-02-02: long (nullable = true)
#  |-- 2019-02-03: long (nullable = true)
#  |-- 2019-02-04: long (nullable = true)
#  |-- 2019-02-05: long (nullable = true)
#  |-- 2019-02-06: long (nullable = true)
#  |-- 2019-02-07: long (nullable = true)
#  |-- 2019-02-08: long (nullable = true)
#  |-- 2019-02-09: long (nullable = true)
#  |-- 2019-02-10: long (nullable = true)
#  |-- 2019-02-11: long (nullable = true)
#  |-- 2019-02-12: long (nullable = true)
#  |-- 2019-02-13: long (nullable = true)
#  |-- 2019-02-14: long (nullable = true)
#  |-- 2019-02-15: long (nullable = true)
#  |-- 2019-02-16: long (nullable = true)
#  |-- 2019-02-17: long (nullable = true)
#  |-- 2019-02-18: long (nullable = true)
#  |-- 2019-02-19: long (nullable = true)
#  |-- 2019-02-20: long (nullable = true)
#  |-- 2019-02-21: long (nullable = true)
#  |-- 2019-02-22: long (nullable = true)
#  |-- 2019-02-23: long (nullable = true)
#  |-- 2019-02-24: long (nullable = true)
#  |-- 2019-02-25: long (nullable = true)
#  |-- 2019-02-26: long (nullable = true)
#  |-- 2019-02-27: long (nullable = true)
#  |-- 2019-02-28: long (nullable = true)
#  |-- 2019-03-01: long (nullable = true)
#  |-- 2019-03-02: long (nullable = true)
#  |-- 2019-03-03: long (nullable = true)
#  |-- 2019-03-04: long (nullable = true)
#  |-- 2019-03-05: long (nullable = true)
#  |-- 2019-03-06: long (nullable = true)
#  |-- 2019-03-07: long (nullable = true)
#  |-- 2019-03-08: long (nullable = true)
#  |-- 2019-03-09: long (nullable = true)
#  |-- 2019-03-10: long (nullable = true)
#  |-- 2019-03-11: long (nullable = true)
#  |-- 2019-03-12: long (nullable = true)
#  |-- 2019-03-13: long (nullable = true)
#  |-- 2019-03-14: long (nullable = true)
#  |-- 2019-03-15: long (nullable = true)
#  |-- 2019-03-16: long (nullable = true)
#  |-- 2019-03-17: long (nullable = true)
#  |-- 2019-03-18: long (nullable = true)
#  |-- 2019-03-19: long (nullable = true)
#  |-- 2019-03-20: long (nullable = true)
#  |-- 2019-03-21: long (nullable = true)
#  |-- 2019-03-22: long (nullable = true)
#  |-- 2019-03-23: long (nullable = true)
#  |-- 2019-03-24: long (nullable = true)
#  |-- 2019-03-25: long (nullable = true)
#  |-- 2019-03-26: long (nullable = true)
#  |-- 2019-03-27: long (nullable = true)
#  |-- 2019-03-28: long (nullable = true)
#  |-- 2019-03-29: long (nullable = true)
#  |-- 2019-03-30: long (nullable = true)
#  |-- 2019-03-31: long (nullable = true)
#  |-- 2019-04-01: long (nullable = true)
#  |-- 2019-04-02: long (nullable = true)
#  |-- 2019-04-03: long (nullable = true)
#  |-- 2019-04-04: long (nullable = true)
#  |-- 2019-04-05: long (nullable = true)
#  |-- 2019-04-06: long (nullable = true)
#  |-- 2019-04-07: long (nullable = true)
#  |-- 2019-04-08: long (nullable = true)
#  |-- 2019-04-09: long (nullable = true)
#  |-- 2019-04-10: long (nullable = true)
#  |-- 2019-04-11: long (nullable = true)
#  |-- 2019-04-12: long (nullable = true)
#  |-- 2019-04-13: long (nullable = true)
#  |-- 2019-04-14: long (nullable = true)
#  |-- 2019-04-15: long (nullable = true)
#  |-- 2019-04-16: long (nullable = true)
#  |-- 2019-04-17: long (nullable = true)
#  |-- 2019-04-18: long (nullable = true)
#  |-- 2019-04-19: long (nullable = true)
#  |-- 2019-04-20: long (nullable = true)
#  |-- 2019-04-21: long (nullable = true)
#  |-- 2019-04-22: long (nullable = true)
#  |-- 2019-04-23: long (nullable = true)
#  |-- 2019-04-24: long (nullable = true)
#  |-- 2019-04-25: long (nullable = true)
#  |-- 2019-04-26: long (nullable = true)
#  |-- 2019-04-27: long (nullable = true)
#  |-- 2019-04-28: long (nullable = true)
#  |-- 2019-04-29: long (nullable = true)
#  |-- 2019-04-30: long (nullable = true)
#  |-- 2019-05-01: long (nullable = true)
#  |-- 2019-05-02: long (nullable = true)
#  |-- 2019-05-03: long (nullable = true)
#  |-- 2019-05-04: long (nullable = true)
#  |-- 2019-05-05: long (nullable = true)
#  |-- 2019-05-06: long (nullable = true)
#  |-- 2019-05-07: long (nullable = true)
#  |-- 2019-05-08: long (nullable = true)
#  |-- 2019-05-09: long (nullable = true)
#  |-- 2019-05-10: long (nullable = true)
#  |-- 2019-05-11: long (nullable = true)
#  |-- 2019-05-12: long (nullable = true)
#  |-- 2019-05-13: long (nullable = true)
#  |-- 2019-05-14: long (nullable = true)
#  |-- 2019-05-15: long (nullable = true)
#  |-- 2019-05-16: long (nullable = true)
#  |-- 2019-05-17: long (nullable = true)
#  |-- 2019-05-18: long (nullable = true)
#  |-- 2019-05-19: long (nullable = true)
#  |-- 2019-05-20: long (nullable = true)
#  |-- 2019-05-21: long (nullable = true)
#  |-- 2019-05-22: long (nullable = true)
#  |-- 2019-05-23: long (nullable = true)
#  |-- 2019-05-24: long (nullable = true)
#  |-- 2019-05-25: long (nullable = true)
#  |-- 2019-05-26: long (nullable = true)
#  |-- 2019-05-27: long (nullable = true)
#  |-- 2019-05-28: long (nullable = true)
#  |-- 2019-05-29: long (nullable = true)
#  |-- 2019-05-30: long (nullable = true)
#  |-- 2019-05-31: long (nullable = true)
#  |-- 2019-06-01: long (nullable = true)
#  |-- 2019-06-02: long (nullable = true)
#  |-- 2019-06-03: long (nullable = true)
#  |-- 2019-06-04: long (nullable = true)
#  |-- 2019-06-05: long (nullable = true)
#  |-- 2019-06-06: long (nullable = true)
#  |-- 2019-06-07: long (nullable = true)
#  |-- 2019-06-08: long (nullable = true)
#  |-- 2019-06-09: long (nullable = true)
#  |-- 2019-06-10: long (nullable = true)
#  |-- 2019-06-11: long (nullable = true)
#  |-- 2019-06-12: long (nullable = true)
#  |-- 2019-06-13: long (nullable = true)
#  |-- 2019-06-14: long (nullable = true)
#  |-- 2019-06-15: long (nullable = true)
#  |-- 2019-06-16: long (nullable = true)
#  |-- 2019-06-17: long (nullable = true)
#  |-- 2019-06-18: long (nullable = true)
#  |-- 2019-06-19: long (nullable = true)
#  |-- 2019-06-20: long (nullable = true)
#  |-- 2019-06-21: long (nullable = true)
#  |-- 2019-06-22: long (nullable = true)
#  |-- 2019-06-23: long (nullable = true)
#  |-- 2019-06-24: long (nullable = true)
#  |-- 2019-06-25: long (nullable = true)
#  |-- 2019-06-26: long (nullable = true)
#  |-- 2019-06-27: long (nullable = true)
#  |-- 2019-06-28: long (nullable = true)
#  |-- 2019-06-29: long (nullable = true)
#  |-- 2019-06-30: long (nullable = true)
#  |-- 2019-07-01: long (nullable = true)
#  |-- 2019-07-02: long (nullable = true)
#  |-- 2019-07-03: long (nullable = true)
#  |-- 2019-07-04: long (nullable = true)
#  |-- 2019-07-05: long (nullable = true)
#  |-- 2019-07-06: long (nullable = true)
#  |-- 2019-07-07: long (nullable = true)
#  |-- 2019-07-08: long (nullable = true)
#  |-- 2019-07-09: long (nullable = true)
#  |-- 2019-07-10: long (nullable = true)
#  |-- 2019-07-11: long (nullable = true)
#  |-- 2019-07-12: long (nullable = true)
#  |-- 2019-07-13: long (nullable = true)
#  |-- 2019-07-14: long (nullable = true)
#  |-- 2019-07-15: long (nullable = true)
#  |-- 2019-07-16: long (nullable = true)
#  |-- 2019-07-17: long (nullable = true)
#  |-- 2019-07-18: long (nullable = true)
#  |-- 2019-07-19: long (nullable = true)
#  |-- 2019-07-20: long (nullable = true)
#  |-- 2019-07-21: long (nullable = true)
#  |-- 2019-07-22: long (nullable = true)
#  |-- 2019-07-23: long (nullable = true)
#  |-- 2019-07-24: long (nullable = true)
#  |-- 2019-07-25: long (nullable = true)
#  |-- 2019-07-26: long (nullable = true)
#  |-- 2019-07-27: long (nullable = true)
#  |-- 2019-07-28: long (nullable = true)
#  |-- 2019-07-29: long (nullable = true)
#  |-- 2019-07-30: long (nullable = true)
#  |-- 2019-07-31: long (nullable = true)
#  |-- 2019-08-01: long (nullable = true)
#  |-- 2019-08-02: long (nullable = true)
#  |-- 2019-08-03: long (nullable = true)
#  |-- 2019-08-04: long (nullable = true)
#  |-- 2019-08-05: long (nullable = true)
#  |-- 2019-08-06: long (nullable = true)
#  |-- 2019-08-07: long (nullable = true)
#  |-- 2019-08-08: long (nullable = true)
#  |-- 2019-08-09: long (nullable = true)
#  |-- 2019-08-10: long (nullable = true)
#  |-- 2019-08-11: long (nullable = true)
#  |-- 2019-08-12: long (nullable = true)
#  |-- 2019-08-13: long (nullable = true)
#  |-- 2019-08-14: long (nullable = true)
#  |-- 2019-08-15: long (nullable = true)
#  |-- 2019-08-16: long (nullable = true)
#  |-- 2019-08-17: long (nullable = true)
#  |-- 2019-08-18: long (nullable = true)
#  |-- 2019-08-19: long (nullable = true)
#  |-- 2019-08-20: long (nullable = true)
#  |-- 2019-08-21: long (nullable = true)
#  |-- 2019-08-22: long (nullable = true)
#  |-- 2019-08-23: long (nullable = true)
#  |-- 2019-08-24: long (nullable = true)
#  |-- 2019-08-25: long (nullable = true)
#  |-- 2019-08-26: long (nullable = true)
#  |-- 2019-08-27: long (nullable = true)
#  |-- 2019-08-28: long (nullable = true)
#  |-- 2019-08-29: long (nullable = true)
#  |-- 2019-08-30: long (nullable = true)
#  |-- 2019-08-31: long (nullable = true)
#  |-- 2019-09-01: long (nullable = true)
# (None, 882517)

# %%
test_dataset = dataset.sample(0.1)
test_dataset.cache()
test_dataset.count()
# Out:
# 88424

# %% [markdown]
# We uses a list of datestrings to vectorize a group of columns. We define the period which we will use for rolling evaluation of the model loss.

# %%
from datetime import datetime, timedelta

training_period=7*12
period = 7
start_date = datetime.strptime("2019-01-01", "%Y-%m-%d")

def get_name(t): 
    return (start_date + timedelta(t)).strftime("%Y-%m-%d")

train_dates = [get_name(t) for t in range(training_period)]
validate_dates = [get_name(training_period+t) for t in range(period)]
retrain_dates = [get_name(period+t) for t in range(training_period)]
test_dates = [get_name(training_period+period+t) for t in range(period)]

# %%
from pyspark.ml import Pipeline
from pyspark.ml.linalg import Vectors, VectorUDT
from pyspark.ml.feature import (
    VectorAssembler, 
    Imputer, 
    SQLTransformer, 
    StandardScaler
)
from pyspark.ml.regression import GeneralizedLinearRegression
import numpy as np


def assembler(output_name, input_dates):
    return  VectorAssembler(
        inputCols = input_dates,
        outputCol = output_name
    ).setHandleInvalid("keep")


pipeline = Pipeline(stages=[
    assembler("train", train_dates),
    assembler("validate", validate_dates),
    assembler("retrain", retrain_dates),
    assembler("test", test_dates),
])


learning_window = (
    pipeline
    .fit(test_dataset)
    .transform(test_dataset)
    .selectExpr(
        "page_id", 
        "train", 
        "validate",
        "retrain",
        "test"
    )
)
learning_window.show(n=5)
learning_window.printSchema()
# Out:
# +-------+--------------------+--------------------+--------------------+--------------------+
# |page_id|               train|            validate|             retrain|                test|
# +-------+--------------------+--------------------+--------------------+--------------------+
# |   8075|[265.0,320.0,342....|[316.0,304.0,335....|[350.0,358.0,363....|[403.0,363.0,454....|
# |  15846|[241.0,243.0,372....|[NaN,NaN,NaN,NaN,...|[278.0,277.0,291....|[NaN,NaN,NaN,NaN,...|
# |  17043|[238.0,345.0,350....|[405.0,336.0,358....|[442.0,384.0,404....|[354.0,288.0,309....|
# |  18730|[123.0,185.0,199....|[220.0,178.0,187....|[210.0,185.0,148....|[174.0,182.0,185....|
# |  33862|[362.0,495.0,493....|[557.0,432.0,428....|[531.0,434.0,448....|[583.0,543.0,522....|
# +-------+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows
#
# root
#  |-- page_id: long (nullable = true)
#  |-- train: vector (nullable = true)
#  |-- validate: vector (nullable = true)
#  |-- retrain: vector (nullable = true)
#  |-- test: vector (nullable = true)

# %%
@F.udf(VectorUDT())
def fill0(vec):
    return Vectors.dense(np.nan_to_num(vec))


@F.udf(VectorUDT())
def denoise(vec, window_size=7):    
    # Create a new matrix for every row that is matrix of size (T//window_size, window_size)
    T = vec.shape[0]
    indexer = np.arange(window_size).reshape(1, -1) + window_size * np.arange(
        T // window_size
    ).reshape(-1, 1)

    # A page is made up of many windows
    page = vec[indexer]
    imputed = np.nan_to_num(page)
    scaled = imputed - imputed.mean(axis=0)
    u, s, vh = np.linalg.svd(scaled, full_matrices=False)
    
    k = window_size-1
    return Vectors.dense(u[:,:k].dot(np.diag(s[:k])).dot(vh[:k]).reshape(-1))


learning_window.select(denoise("train")).show(n=5)
# Out:
# +--------------------+
# |      denoise(train)|
# +--------------------+
# |[-73.170450752947...|
# |[172.166666666666...|
# |[-170.27860447096...|
# |[-71.091683780098...|
# |[-148.75455166942...|
# +--------------------+
# only showing top 5 rows

# %%
poisson_regression = GeneralizedLinearRegression(
    family="poisson", 
    link="log",
    maxIter=10, 
    regParam=0.3,
)
poisson_regression.fit(
    learning_window
    .select(
        denoise("train").alias("features"), 
        F.expr(f"{validate_dates[0]} as label")
    )
)
# Out:
# GeneralizedLinearRegression_6e3af0ae7958

# %%
learning_window_full = (
    pipeline
    .fit(dataset)
    .transform(dataset)
    .selectExpr(
        "page_id", 
        "train", 
        "validate",
        "retrain",
        "test"
    )
)
model_full = poisson_regression.fit(
    learning_window_full
    .select(
        denoise("train").alias("features"), 
        F.expr(f"{validate_dates[0]} as label")
    )
)
prediction = model_full.transform(learning_window_full.withColumn("features", denoise("retrain")))
prediction.select("page_id", "train", "validate", "retrain", "test", "prediction").show()
# Out:
# +-------+--------------------+--------------------+--------------------+--------------------+------------------+
# |page_id|               train|            validate|             retrain|                test|        prediction|
# +-------+--------------------+--------------------+--------------------+--------------------+------------------+
# |   1677|[256.0,357.0,391....|[586.0,406.0,341....|[370.0,388.0,390....|[344.0,380.0,315....| 1989.999999997957|
# |   1697|[451.0,617.0,600....|[472.0,467.0,588....|[635.0,670.0,617....|[463.0,447.0,667....| 1989.999999997966|
# |   1806|[3655.0,5033.0,50...|[4491.0,4868.0,39...|[5780.0,5199.0,51...|[4122.0,4105.0,48...|1989.9999999981374|
# |   1950|[1191.0,361.0,269...|[484.0,485.0,468....|[379.0,505.0,440....|[563.0,585.0,650....| 1989.999999997996|
# |   2927|[502.0,524.0,529....|[498.0,538.0,583....|[504.0,461.0,451....|[480.0,481.0,435....|1989.9999999979145|
# |   3764|[981.0,1564.0,169...|[1365.0,1403.0,13...|[1669.0,1627.0,16...|[1579.0,1556.0,15...|1989.9999999978386|
# |   4823|[268.0,323.0,347....|[530.0,515.0,472....|[439.0,435.0,478....|[493.0,496.0,459....|1989.9999999979482|
# |   5385|[201.0,336.0,338....|[343.0,346.0,358....|[396.0,430.0,408....|[391.0,392.0,391....|1989.9999999979023|
# |   5556|[NaN,NaN,NaN,NaN,...|[121.0,142.0,142....|[132.0,112.0,143....|[141.0,125.0,129....|1989.9999999978616|
# |   6721|[215.0,319.0,330....|[168.0,129.0,146....|[355.0,316.0,301....|[145.0,123.0,127....|1989.9999999978809|
# |   7279|[154.0,296.0,362....|[282.0,267.0,249....|[484.0,424.0,426....|[349.0,294.0,245....| 1989.999999997927|
# |   8075|[265.0,320.0,342....|[316.0,304.0,335....|[350.0,358.0,363....|[403.0,363.0,454....| 1989.999999997927|
# |   8484|[358.0,376.0,393....|[424.0,404.0,385....|[329.0,352.0,364....|[327.0,350.0,338....|1989.9999999979711|
# |   9978|[176.0,239.0,229....|[220.0,253.0,243....|[281.0,300.0,281....|[262.0,327.0,292....|1989.9999999979375|
# |  11619|[NaN,NaN,NaN,NaN,...|[NaN,NaN,NaN,NaN,...|[NaN,NaN,NaN,NaN,...|[NaN,NaN,NaN,NaN,...|1989.9999999979145|
# |  11625|[917.0,1349.0,131...|[1300.0,1323.0,12...|[2350.0,1792.0,14...|[1176.0,1258.0,12...| 1989.999999997188|
# |  13098|[NaN,NaN,NaN,112....|[104.0,NaN,NaN,Na...|[NaN,NaN,NaN,NaN,...|[105.0,NaN,NaN,Na...|1989.9999999979093|
# |  14117|[233.0,353.0,353....|[311.0,350.0,308....|[422.0,455.0,479....|[373.0,351.0,335....| 1989.999999997927|
# |  15237|[NaN,124.0,142.0,...|[242.0,230.0,247....|[204.0,208.0,217....|[251.0,260.0,215....|1989.9999999979445|
# |  15663|[NaN,151.0,NaN,10...|[NaN,NaN,NaN,NaN,...|[124.0,150.0,165....|[NaN,NaN,NaN,NaN,...| 1989.999999997865|
# +-------+--------------------+--------------------+--------------------+--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Appendix

# %%
x = learning_window.select(normalize("train").alias("train")).first()
x

import numpy as np

x.train
imputed = np.nan_to_num(x)

# Create a new matrix for every row that is matrix of size (T//window_size, window_size)
T = x.train.shape[0]
window_size=7
indexer = np.arange(window_size).reshape(1, -1) + window_size * np.arange(
    T // window_size
).reshape(-1, 1)

# A page is made up of many windows
page = x.train[indexer]
print(page)

u, s, vh = np.linalg.svd(page, full_matrices=False)


u.shape, s.shape, vh.shape

k=7
a1 = u[:,:k].dot(np.diag(s[:k])).dot(vh[:k])
print(np.allclose(x, a1.reshape(-1)))
k=6
a2 = u[:,:k].dot(np.diag(s[:k])).dot(vh[:k])
print(np.allclose(x, a2.reshape(-1)))

(a1-a2).astype(int)

page - page.mean(axis=0).shape
